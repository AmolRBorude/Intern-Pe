# %% [markdown]
# <a href="https://colab.research.google.com/github/AmolRBorude/Mchine-Learning-Project/blob/master/Car_Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
car = pd.read_csv('/content/drive/MyDrive/Collab Dataset/quikr_car.csv')

# %%
car.shape
# Out:
# (892, 6)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
car = car.dropna(subset=['year'])

# %%
car = car[car['year'].str.isnumeric()]

# %%
car['year'] = car['year'].astype(int)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 842 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        842 non-null    object
#  1   company     842 non-null    object
#  2   year        842 non-null    int64
#  3   Price       842 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 46.0+ KB

# %%
car
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 886                    Toyota Corolla Altis     Toyota  2009       3,00,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#        kms_driven fuel_type
# ...

# %%
car['Price'].isna().sum
# Out:
# <bound method Series.sum of 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 888    False
# 889    False
# 890    False
# 891    False
# Name: Price, Length: 842, dtype: bool>

# %%
car.reset_index()
# Out:
#      index                                    name    company  year  \
# 0        0    Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007
# 1        1                 Mahindra Jeep CL550 MDI   Mahindra  2006
# 2        2              Maruti Suzuki Alto 800 Vxi     Maruti  2018
# 3        3  Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014
# 4        4        Ford EcoSport Titanium 1.5L TDCi       Ford  2014
# ..     ...                                     ...        ...   ...
# 837    886                    Toyota Corolla Altis     Toyota  2009
# 838    888                     Tata Zest XM Diesel       Tata  2018
# 839    889                      Mahindra Quanto C8   Mahindra  2013
# 840    890                Honda Amaze 1.2 E i VTEC      Honda  2014
# 841    891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014
#
#              Price    kms_driven fuel_type
# 0           80,000    45,000 kms    Petrol
# 1         4,25,000        40 kms    Diesel
# ...

# %%
car.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
car= car[car['Price']!='Ask For Price']

# %%
car['Price'] = car['Price'].str.replace(',','').astype(int)
# Out:
# <ipython-input-16-6e93234955de>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car['Price'] = car['Price'].str.replace(',','').astype(int)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 819 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        819 non-null    object
#  1   company     819 non-null    object
#  2   year        819 non-null    int64
#  3   Price       819 non-null    int64
#  4   kms_driven  819 non-null    object
#  5   fuel_type   816 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 44.8+ KB

# %%
car['kms_driven']= car['kms_driven'].str.split(' ').str.get(0).str.replace(',','')
# Out:
# <ipython-input-18-8c6d6d3af924>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car['kms_driven']= car['kms_driven'].str.split(' ').str.get(0).str.replace(',','')

# %%
car=car[car['kms_driven'].str.isnumeric()]

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 817 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        817 non-null    object
#  1   company     817 non-null    object
#  2   year        817 non-null    int64
#  3   Price       817 non-null    int64
#  4   kms_driven  817 non-null    object
#  5   fuel_type   816 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 44.7+ KB

# %%
car
# Out:
#                                        name   company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000
# 6                                 Ford Figo      Ford  2012  175000
# ..                                      ...       ...   ...     ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011  270000
# 885               Tata Indica V2 DLE BS III      Tata  2009  110000
# 886                    Toyota Corolla Altis    Toyota  2009  300000
# 888                     Tata Zest XM Diesel      Tata  2018  260000
# 889                      Mahindra Quanto C8  Mahindra  2013  390000
#
#     kms_driven fuel_type
# 0        45000    Petrol
# 1           40    Diesel
# 3        28000    Petrol
# 4        36000    Diesel
# ...

# %%
car['kms_driven'] = car['kms_driven'].astype(int)
# Out:
# <ipython-input-23-7bcfc74e04c9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car['kms_driven'] = car['kms_driven'].astype(int)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 817 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        817 non-null    object
#  1   company     817 non-null    object
#  2   year        817 non-null    int64
#  3   Price       817 non-null    int64
#  4   kms_driven  817 non-null    int64
#  5   fuel_type   816 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 44.7+ KB

# %%
car = car.dropna(subset=['fuel_type'])

# %%
car= car.reset_index()

# %%
car
# Out:
#      index                                    name   company  year   Price  \
# 0        0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000
# 1        1                 Mahindra Jeep CL550 MDI  Mahindra  2006  425000
# 2        3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000
# 3        4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000
# 4        6                               Ford Figo      Ford  2012  175000
# ..     ...                                     ...       ...   ...     ...
# 811    883              Maruti Suzuki Ritz VXI ABS    Maruti  2011  270000
# 812    885               Tata Indica V2 DLE BS III      Tata  2009  110000
# 813    886                    Toyota Corolla Altis    Toyota  2009  300000
# 814    888                     Tata Zest XM Diesel      Tata  2018  260000
# 815    889                      Mahindra Quanto C8  Mahindra  2013  390000
#
#      kms_driven fuel_type
# 0         45000    Petrol
# ...

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       816 non-null    int64
#  1   name        816 non-null    object
#  2   company     816 non-null    object
#  3   year        816 non-null    int64
#  4   Price       816 non-null    int64
#  5   kms_driven  816 non-null    int64
#  6   fuel_type   816 non-null    object
# dtypes: int64(4), object(3)
# memory usage: 44.8+ KB

# %%
car['name'] = car['name'].str.split(' ').str.slice(0,3).str.join(' ')

# %%
car
# Out:
#      index                    name   company  year   Price  kms_driven  \
# 0        0     Hyundai Santro Xing   Hyundai  2007   80000       45000
# 1        1     Mahindra Jeep CL550  Mahindra  2006  425000          40
# 2        3       Hyundai Grand i10   Hyundai  2014  325000       28000
# 3        4  Ford EcoSport Titanium      Ford  2014  575000       36000
# 4        6               Ford Figo      Ford  2012  175000       41000
# ..     ...                     ...       ...   ...     ...         ...
# 811    883      Maruti Suzuki Ritz    Maruti  2011  270000       50000
# 812    885          Tata Indica V2      Tata  2009  110000       30000
# 813    886    Toyota Corolla Altis    Toyota  2009  300000      132000
# 814    888            Tata Zest XM      Tata  2018  260000       27000
# 815    889      Mahindra Quanto C8  Mahindra  2013  390000       40000
#
#     fuel_type
# 0      Petrol
# 1      Diesel
# 2      Petrol
# 3      Diesel
# 4      Diesel
# ..        ...
# ...

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       816 non-null    int64
#  1   name        816 non-null    object
#  2   company     816 non-null    object
#  3   year        816 non-null    int64
#  4   Price       816 non-null    int64
#  5   kms_driven  816 non-null    int64
#  6   fuel_type   816 non-null    object
# dtypes: int64(4), object(3)
# memory usage: 44.8+ KB

# %%
car = car.reset_index(drop=True)

# %%
car
# Out:
#      index                    name   company  year   Price  kms_driven  \
# 0        0     Hyundai Santro Xing   Hyundai  2007   80000       45000
# 1        1     Mahindra Jeep CL550  Mahindra  2006  425000          40
# 2        3       Hyundai Grand i10   Hyundai  2014  325000       28000
# 3        4  Ford EcoSport Titanium      Ford  2014  575000       36000
# 4        6               Ford Figo      Ford  2012  175000       41000
# ..     ...                     ...       ...   ...     ...         ...
# 811    883      Maruti Suzuki Ritz    Maruti  2011  270000       50000
# 812    885          Tata Indica V2      Tata  2009  110000       30000
# 813    886    Toyota Corolla Altis    Toyota  2009  300000      132000
# 814    888            Tata Zest XM      Tata  2018  260000       27000
# 815    889      Mahindra Quanto C8  Mahindra  2013  390000       40000
#
#     fuel_type
# 0      Petrol
# 1      Diesel
# 2      Petrol
# 3      Diesel
# 4      Diesel
# ..        ...
# ...

# %%
car.describe()
# Out:
#             index         year         Price     kms_driven
# count  816.000000   816.000000  8.160000e+02     816.000000
# mean   431.637255  2012.444853  4.117176e+05   46275.531863
# std    254.197374     4.002992  4.751844e+05   34297.428044
# min      0.000000  1995.000000  3.000000e+04       0.000000
# 25%    212.750000  2010.000000  1.750000e+05   27000.000000
# 50%    427.500000  2013.000000  2.999990e+05   41000.000000
# 75%    652.250000  2015.000000  4.912500e+05   56818.500000
# max    889.000000  2019.000000  8.500003e+06  400000.000000

# %%
car=car[car['Price']<6e6]

# %%
car
# Out:
#      index                    name   company  year   Price  kms_driven  \
# 0        0     Hyundai Santro Xing   Hyundai  2007   80000       45000
# 1        1     Mahindra Jeep CL550  Mahindra  2006  425000          40
# 2        3       Hyundai Grand i10   Hyundai  2014  325000       28000
# 3        4  Ford EcoSport Titanium      Ford  2014  575000       36000
# 4        6               Ford Figo      Ford  2012  175000       41000
# ..     ...                     ...       ...   ...     ...         ...
# 811    883      Maruti Suzuki Ritz    Maruti  2011  270000       50000
# 812    885          Tata Indica V2      Tata  2009  110000       30000
# 813    886    Toyota Corolla Altis    Toyota  2009  300000      132000
# 814    888            Tata Zest XM      Tata  2018  260000       27000
# 815    889      Mahindra Quanto C8  Mahindra  2013  390000       40000
#
#     fuel_type
# 0      Petrol
# 1      Diesel
# 2      Petrol
# 3      Diesel
# 4      Diesel
# ..        ...
# ...

# %%
car.describe()
# Out:
#             index         year         Price     kms_driven
# count  815.000000   815.000000  8.150000e+02     815.000000
# mean   431.477301  2012.442945  4.017933e+05   46277.096933
# std    254.312373     4.005079  3.815888e+05   34318.459638
# min      0.000000  1995.000000  3.000000e+04       0.000000
# 25%    212.500000  2010.000000  1.750000e+05   27000.000000
# 50%    427.000000  2013.000000  2.999990e+05   41000.000000
# 75%    652.500000  2015.000000  4.900000e+05   56879.000000
# max    889.000000  2019.000000  3.100000e+06  400000.000000

# %%
X = car.drop(columns='Price')

# %%
X=car.drop(columns='Price')

# %%
car.to_csv('Cleaned_Car.csv')

# %%
X
# Out:
#      index                    name   company  year  kms_driven fuel_type
# 0        0     Hyundai Santro Xing   Hyundai  2007       45000    Petrol
# 1        1     Mahindra Jeep CL550  Mahindra  2006          40    Diesel
# 2        3       Hyundai Grand i10   Hyundai  2014       28000    Petrol
# 3        4  Ford EcoSport Titanium      Ford  2014       36000    Diesel
# 4        6               Ford Figo      Ford  2012       41000    Diesel
# ..     ...                     ...       ...   ...         ...       ...
# 811    883      Maruti Suzuki Ritz    Maruti  2011       50000    Petrol
# 812    885          Tata Indica V2      Tata  2009       30000    Diesel
# 813    886    Toyota Corolla Altis    Toyota  2009      132000    Petrol
# 814    888            Tata Zest XM      Tata  2018       27000    Diesel
# 815    889      Mahindra Quanto C8  Mahindra  2013       40000    Diesel
#
# [815 rows x 6 columns]

# %%
y = car['Price']

# %%
y
# Out:
# 0       80000
# 1      425000
# 2      325000
# 3      575000
# 4      175000
#         ...
# 811    270000
# 812    110000
# 813    300000
# 814    260000
# 815    390000
# Name: Price, Length: 815, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
ohe=OneHotEncoder()
ohe.fit(X[['name','company','fuel_type']])
# Out:
# OneHotEncoder()

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['name','company','fuel_type']))

# %%
lr=LinearRegression()

# %%
pipe=make_pipeline(column_trans,lr)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#        'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#        'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#        'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat Diesel',
#        'Chevrolet Beat LS...
#                                                                             array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#        'Hindustan', 'Honda', 'Hyundai', 'Jaguar', 'Jeep', 'Land',
#        'Mahindra', 'Maruti', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan',
#        'Renault', 'Skoda', 'Tata', 'Toyota', 'Volkswagen', 'Volvo'],
#       dtype=object),
# ...

# %%
y
# Out:
# 0       80000
# 1      425000
# 2      325000
# 3      575000
# 4      175000
#         ...
# 811    270000
# 812    110000
# 813    300000
# 814    260000
# 815    390000
# Name: Price, Length: 815, dtype: int64

# %%
y_pred = pipe.predict(X_test)

# %%
y_pred
# Out:
# array([ 277232.68186452,  346333.41000603, 1024143.64656515,
#         413992.24116743,  375155.96358492,  564665.09896077,
#         231998.6231691 ,  224998.07725727,  461381.15793589,
#         358325.80483685,  699500.11278461,  267502.68599716,
#        1208124.6537741 ,  444998.53620968,  207205.87119535,
#         278335.95355591,  240504.05661434,  178249.97747759,
#          97777.81129214,   97777.81129214,  207205.87119535,
#         207205.87119535,  527584.07709278,  277232.68186452,
#         171720.15487835,  206249.48436536,  274497.86857997,
#         640744.61952057,  375000.56467633,   97777.81129214,
#          70007.5001522 , 1174130.84180847,  250153.31325643,
#         250153.31325643,  243238.86989889, 1219496.3142457 ,
#         278335.95355591,  500999.44247047,  207205.87119535,
#          90100.97801072,   90100.97801072,  990149.83459952,
#         207205.87119535,   95250.73538214,  119497.10282418,
# ...

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7054479431007363

# %%
scores=[]
for i in range (1000):
  X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=i)
  lr=LinearRegression()
  pipe=make_pipeline(column_trans,lr)
  pipe.fit(X_train,y_train)
  y_pred=pipe.predict(X_test)
  scores.append(r2_score(y_test,y_pred))

# %%
np.argmax(scores)
# Out:
# np.int64(124)

# %%
scores[np.argmax(scores)]
# Out:
# 0.8480692189829477

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=np.argmax(scores))
lr=LinearRegression()
pipe=make_pipeline(column_trans,lr)
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.8480692189829477

# %%
import pickle
pickle.dump(pipe,open('LinearRegressionmodel.pkl','wb'))

# %%
pipe.predict(pd.DataFrame([['Maruti Suzuki Swift','Maruti',2019,100,'Petrol']],columns=['name','company','year','kms_driven','fuel_type']))
# Out:
# array([268093.3804359])
